# %% [markdown]
# **주제**
# 프리미어리그 축구 데이터 분석

# %% [markdown]
# **프로젝트 이름**  프리미어리그 축구 분석
#
# 1.   승패 분석
# 2.   승률 분석

# %% [markdown]
# (1) 주제 선정 이유 : 축구에 관심을 가지고 있으면 팀들의 성적과 승패에 대해서 알아보고 싶어서다.

# %% [markdown]
# (2) 가설 정의:
#
# > 1. 내가 좋아하는 축구 클럽의 최근 성적을 불러온다.(우승 성적/ 현재 성적)
#
#
#
# > 2. 우승성적과 현재 성적을 비교하며 부족한 부분에 대해 파악한다.
#
#
#
# > 3. 비교해서 파악한 데이터를 가지고 축구 클럽의 문제점을 알아낸다.

# %% [markdown]
# (3) 인터넷을 통한 데이터 획득 + (7) 참고문헌:
#
# > 1. https://www.kaggle.com/datasets/irkaal/english-premier-league-results?resource=download 에서 최근 프리미어리그 성적을 파악한다.(result.csv 다운함)
#
#
# > 2. 작동이 안될때 참조한 사이트들
#   - https://wikidocs.net/book/1 에서 파이선에 대한 정보를 가지고 왔다.(문법)
#   - Pandas : https://pandas.pydata.org/ <br> (pandas안될때)
#   - matplotlib : 특정 사이트보단 구글링 하면서 크롤링하였다.
#   - *https://jaaamj.tistory.com/112 / https://enthan.tistory.com/17 / https://wikidocs.net/86290 /
#
#
# > 3. 모르거나 데이터가 막혀서 안되는 부분은 구글링 또는유튜브를 참조하였다.

# %% [markdown]
# (4) 분석을 위한 데이터의 가공:
# 1. 최근 프리미어리그의 데이터를 모아놓은 csv를 pandas를 이용하여 데이터를 읽었다. 그리고 pandas를 통해서 홈팀과 어웨이팀의 승패를 보여주는 표를 출력하였다.
# 2. pandas를 이용하여 읽은 데이터를 통해 seaborn과 matplotlib를 통해 데이터를 가공 및 도표로 자신이 원하는 팀에 대한 득점, 실점, 승률, 골득점율 등 축구 데이터를 도식화 하여 표로 나타내었다.

# %% [markdown]
# (5) 분석 결과 도출:
#
#
# *   반복문을 통해 Team_List에 있는 팀들을 열거하였다.
# *   pandas를 통해 PL_result.csv의 데이터를 불러온다.
# *   자신이 원하는 홈팀과 어웨이 팀을 PL_result.csv에서 골라서 홈팀과 어웨이팀의 상대 전적에 대해 알아본다.
# *   불러온 데이터에서 불필요한 열의 내용은 제거한다.
# *   PL_result.csv에서 각팀의 데이터에서 나오는 골 수를 모두 더해 총 골수에 대한 도표를 그려냈다.
# *   PL_result.csv에서 하나의 팀에서 치른 모든 경기수에서 이긴 경기수를 나누어 100을 곱해 퍼센트를 나타내는 승률 그래프를 그려냈다,
# *   오류 승률 부분에 몇몇 팀의 승률이 0% 인것을 알 수 있다. 이러한 이유는 팀의 승리한 수가 전체 경기수에 비해 너무나 적기 때문에 반올림 과정에서 0%로 출력되었다.
#
# *   아래에서 Team_List를 반복문 for를 통해 구현함
# *   홈팀과 어웨이 팀을 각각 설정하여 이때까지 치른 경기에 대한 승패를 알 수 있었다.
# *   pandas와 matliplot, seaborn을 이용해 승률과 골득실률에 대한 그래프를 작성하여 시각적으로 상대 팀과의 전적을 알 수 있었다.
#
#
# - 한글깨짐 현상은 해결됨.

# %% [markdown]
# :(6) 결론: 본인의 명제/논리가 증명/확인 되었는지와 이를 구체적으로 서술함
#
#
# - 만들기 전의 명제 : 내가 분석하고 싶은 팀(토트넘)은 다른 팀에 비해 골 수도 적을 것이고 득실 면에서 다른 빅6팀들과 큰 차이가 있을 것이다.
#
# - 만든 후의 명제 확인1 : 골 수와 득실 면에서 큰 차이가 없을 뿐더러 우승을 많이 한 팀보다 더 골수가 많은 것이 확인되었다.
#
# - 만든 후의 명제 확인2 : 승률 면에서는 다른 빅6팀보다 낮은 것이 보였으면 심지어 몇몇 다른 팀보다도 낮은 것이 드러났다.
#
# - 결론 : 팀의 골수를 보았을 때 스트라이커와 윙어와 같은 공격수들의 퀄리티는 높지만 승률이 낮은 것으로 보아 수비진의 부분에서 미흡하다는 것을 알 수 있다. 또한 승률에서 나타나는 것처럼 골수에 비해 승리를 따내지 못하는 팀이다.

# %% [markdown]
# (8) 별첨: (3)의 획득한 데이터 원본 : 알집으로 함께 묶어서 제출 --> (PL_result.csv)

# %% [markdown]
# (9)별첨 : #5 ~ #8까지 PL_result.csv를 가공한 데이터

# %% [markdown]
# (10) 별첨: (3)을 (4)로 변환하는 등의 작업을 위하여 본인이 직접 개발한 Python 소스코드 원본 ---- 아래에 소스코드

# %%
#1 PL_result를 파일선택
from google.colab import files
myfile = files.upload()
# Out:
#      <input type="file" id="files-6d2efeb8-f5a1-4a5a-8571-53f606a803da" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6d2efeb8-f5a1-4a5a-8571-53f606a803da">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#2 third package 불러오기
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %matplotlib inline


#한글 깨짐문제 해결
import matplotlib as mpl 
import matplotlib.font_manager as fm  

# !apt-get update -qq
# !apt-get install fonts-nanum* -qq

path = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf' 
font_name = fm.FontProperties(fname=path, size=10).get_name()
print(font_name)
plt.rc('font', family=font_name)

fm._rebuild()
mpl.rcParams['axes.unicode_minus'] = False

data = pd.read_csv("PL_result.csv",encoding='windows-1254')

#5 data(PL_result) 정보 확인
data.info()
data.isna().sum()

#6 불필요한 열의 내용은 제거한다.
data.drop(['DateTime','HTHG','HTAG','HTR','Referee', 'HS', 'AS','HST','AST', 'HC', 'AC', 'HF','AF', 'HY', 'AY', 'HR', 'AR']
              , axis=1, inplace=True)

#7 새로운 열 내용으로 채우기
data.replace({'H' : 0, 'D' : 1, 'A' : 2}, inplace=True)

#8 unique를 통해 개별 컬럼 내에 유일한 값을 리스트화
team_name = list(data["HomeTeam"].unique())

data_team = pd.DataFrame(columns=team_name, index=["골", "득실"])

#8 골득실 data_team에 널기
for i in team_name:
    data_team[i].골 = sum(data["FTHG"][data["HomeTeam"]== i])
    data_team[i].골 += sum(data["FTAG"][data["AwayTeam"] == i])
    data_team[i].득실 = sum(data["FTAG"][data["HomeTeam"] == i])
    data_team[i].골 += sum(data["FTHG"][data["AwayTeam"] == i])
#8 팀순서는 알파베 ABC 순서   
data_team

#8 전치 행렬 전환한다.
data_team = data_team.T
data_team

data_team = data_team.reset_index()
data_team.rename(columns = {'index' : '팀'}, inplace = True)
df_team_G = data_team.sort_values("골", ascending=False)

#9 seaborn을 이용해서 골득실 그래프로 만들기(한글 깨짐 현상으로 인한 영어 사용)
figure, (ax1,ax2) = plt.subplots(nrows = 1, ncols =2 ) 
figure.set_size_inches(20,16)
sns.barplot(data=df_team_G, x="골", y="팀", ax=ax1)
sns.barplot(data=df_team_G, x="득실", y="팀", ax=ax2)
ax1.set_xlabel("골", fontsize=20)
ax2.set_xlabel("전체 득실", fontsize=20)

#10 승률 그래프제작 
a = 0

#10 새로운 열인 win rate 생성하고 삽입하기
data_team.insert(3, "승률", 0)

#10 2000년대 이후로 설정
i = 0
for i in range(0, 10802):
    season = (data["Season"].loc[i]).split("-")
    mm = int(season[0])
    if mm < 2000:
        data.drop(i, inplace=True)
#10 team이름의 홈팀에서 이긴 경기를 총 경기수로 나누고 100을 곱한 후 2자리에서 반올림한다.
for name in team_name:
    All_match = sum(data["HomeTeam"]==name) + sum(data["AwayTeam"]==name)
    Win_match = sum((data["HomeTeam"]==name) & (data["FTR"]==0))
    Win_match += sum((data["AwayTeam"]==name) & (data["FTR"]==2))
    if All_match == 0:
        continue
    data_team["승률"].loc[a] = round((Win_match/All_match) * 100, 1)
    a = a + 1
    
data_team

#11 seaborn을 통해 승률 그래프 제작

figure, (ax1,ax2) = plt.subplots(nrows = 1, ncols =2 ) 
figure.set_size_inches(20,16)
sns.barplot(data=df_team_G, x="골", y="팀", ax=ax1)
sns.barplot(data=data_team.sort_values("승률", ascending=False), x="승률", y="팀", ax=ax2)
ax1.set_xlabel("골", fontsize=20)
ax2.set_xlabel("승률", fontsize=20)
# Out:
# NanumBarunGothic
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11113 entries, 0 to 11112
# Data columns (total 23 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Season    11113 non-null  object
#  1   DateTime  11113 non-null  object
#  2   HomeTeam  11113 non-null  object
#  3   AwayTeam  11113 non-null  object
#  4   FTHG      11113 non-null  int64
#  5   FTAG      11113 non-null  int64
#  6   FTR       11113 non-null  object
#  7   HTHG      10189 non-null  float64
#  8   HTAG      10189 non-null  float64
#  9   HTR       10189 non-null  object
#  10  Referee   8289 non-null   object
#  11  HS        8289 non-null   float64
#  12  AS        8289 non-null   float64
#  13  HST       8289 non-null   float64
#  14  AST       8289 non-null   float64
#  15  HC        8289 non-null   float64
#  16  AC        8289 non-null   float64
#  17  HF        8289 non-null   float64
#  18  AF        8289 non-null   float64
# ...

# %%
#* 홈팀과 어웨이팀의 상대 전적을 알려주는 프로그램 (팀 네임을 복사해서 붙여 넣어주세요) *
a = 1
b = 0
Team_List = ["Liverpool","Arsenal","Coventry","Aston Villa","QPR","Chelsea","Blackburn","Sheffield Weds","Man City","Oldham","Sheffield United","Newcastle","Leeds","Southampton","Everton","West Ham","Wimbledon","Norwich","Man United","Tottenham","Ipswich","Swindon","Crystal Palace","Nott'm Forest","Leicester","Middlesbrough","Bolton","Derby","Sunderland","Barnsley","Charlton","Bradford","Watford","Fulham"]
for c in Team_List :
  print("(",a,")"," : ", Team_List[b])
  a = a+1
  b = b+1

print("_____________________________________________________________________________________________________")
print("주의 사항_1 : 만약 자신이 원하는 팀이 없을 경우 직접 검색해 영어로 넣어주세요.")
print("주의 사항_2 : 만약에 결과가 안나올 경우 당황하지 마시고 csv파일에 있는 이름을 붙여 넣어주세요.")
# Out:
# ( 1 )  :  Liverpool
# ( 2 )  :  Arsenal
# ( 3 )  :  Coventry
# ( 4 )  :  Aston Villa
# ( 5 )  :  QPR
# ( 6 )  :  Chelsea
# ( 7 )  :  Blackburn
# ( 8 )  :  Sheffield Weds
# ( 9 )  :  Man City
# ( 10 )  :  Oldham
# ( 11 )  :  Sheffield United
# ( 12 )  :  Newcastle
# ( 13 )  :  Leeds
# ( 14 )  :  Southampton
# ( 15 )  :  Everton
# ( 16 )  :  West Ham
# ( 17 )  :  Wimbledon
# ( 18 )  :  Norwich
# ( 19 )  :  Man United
# ( 20 )  :  Tottenham
# ( 21 )  :  Ipswich
# ( 22 )  :  Swindon
# ( 23 )  :  Crystal Palace
# ( 24 )  :  Nott'm Forest
# ( 25 )  :  Leicester
# ( 26 )  :  Middlesbrough
# ( 27 )  :  Bolton
# ( 28 )  :  Derby
# ( 29 )  :  Sunderland
# ( 30 )  :  Barnsley
# ( 31 )  :  Charlton
# ( 32 )  :  Bradford
# ( 33 )  :  Watford
# ( 34 )  :  Fulham
# _____________________________________________________________________________________________________
# 주의 사항_1 : 만약 자신이 원하는 팀이 없을 경우 직접 검색해 영어로 넣어주세요.
# 주의 사항_2 : 만약에 결과가 안나올 경우 당황하지 마시고 csv파일에 있는 이름을 붙여 넣어주세요.

# %%
#4 홈팀과 어웨이팀의 승패 (*위의 팀 알림이에서 복사해서 붙여 넣어주세요*)
print("토막상식1 : FTHG = Full Time Home team Goals = 홈팀의 득점")
print("토막상식2 : FTAG = Full Time Away team Goals = 어웨이팀의 득점")
print("토막상식3 : FTR = Full Time Results = 시합 결과 (0 = 홈팀의 승리 , 1 = 무승부 , 2 = 어웨이팀의 승리 )")
print("_____________________________________________________________________________________________________")

print("보고싶은 팀을 선택해 주세요!!")
home_Team = input("Home Team : ")
away_Team = input("Away Team : ")
print("Selected team(Home : Away) : " + home_Team + " : " + away_Team)

result1 = pd.concat([data[data['HomeTeam']== home_Team], data[data['AwayTeam']== home_Team]]).sort_index()
result2 = pd.concat([result1[result1['AwayTeam']==away_Team]]).sort_index()
result2
# Out:
# 토막상식1 : FTHG = Full Time Home team Goals = 홈팀의 득점
# 토막상식2 : FTAG = Full Time Away team Goals = 어웨이팀의 득점
# 토막상식3 : FTR = Full Time Results = 시합 결과 (0 = 홈팀의 승리 , 1 = 무승부 , 2 = 어웨이팀의 승리 )
# _____________________________________________________________________________________________________
# 보고싶은 팀을 선택해 주세요!!
# Home Team : Man United
# Away Team : Tottenham
# Selected team(Home : Away) : Man United : Tottenham
#         Season    HomeTeam   AwayTeam  FTHG  FTAG  FTR
# 2979   2000-01  Man United  Tottenham     2     0    0
# 3489   2001-02  Man United  Tottenham     4     0    0
# 3644   2002-03  Man United  Tottenham     1     0    0
# 4249   2003-04  Man United  Tottenham     3     0    0
# 4562   2004-05  Man United  Tottenham     0     0    1
# 4814   2005-06  Man United  Tottenham     1     1    1
# 5136   2006-07  Man United  Tottenham     1     0    0
# 5519   2007-08  Man United  Tottenham     1     0    0
# 6197   2008-09  Man United  Tottenham     5     2    0
# ...

# %% [markdown]
# **제작한 과정**

# %%
#2 third package 불러오기
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %matplotlib inline


#한글 깨짐문제 해결
import matplotlib as mpl 
import matplotlib.font_manager as fm  

# !apt-get update -qq
# !apt-get install fonts-nanum* -qq

path = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf' 
font_name = fm.FontProperties(fname=path, size=10).get_name()
print(font_name)
plt.rc('font', family=font_name)

fm._rebuild()
mpl.rcParams['axes.unicode_minus'] = False

data = pd.read_csv("PL_result.csv",encoding='windows-1254')
# Out:
# NanumBarunGothic

# %%
data.tail()
# Out:
#         Season              DateTime     HomeTeam        AwayTeam  FTHG  FTAG  \
# 11108  2021-22  2022-04-09T17:30:00Z  Aston Villa       Tottenham     0     4
# 11109  2021-22  2022-04-10T14:00:00Z    Brentford        West Ham     2     0
# 11110  2021-22  2022-04-10T14:00:00Z    Leicester  Crystal Palace     2     1
# 11111  2021-22  2022-04-10T14:00:00Z      Norwich         Burnley     2     0
# 11112  2021-22  2022-04-10T16:30:00Z     Man City       Liverpool     2     2
#
#       FTR  HTHG  HTAG HTR  ...  HST  AST   HC   AC    HF    AF   HY   AY   HR  \
# 11108   A   0.0   1.0   A  ...  8.0  5.0  9.0  3.0  12.0  14.0  2.0  3.0  0.0
# 11109   H   0.0   0.0   D  ...  7.0  1.0  4.0  6.0   2.0   6.0  0.0  1.0  0.0
# 11110   H   2.0   0.0   H  ...  3.0  3.0  3.0  4.0  11.0  12.0  1.0  1.0  0.0
# 11111   H   1.0   0.0   H  ...  6.0  4.0  6.0  7.0  12.0  10.0  1.0  1.0  0.0
# 11112   D   2.0   1.0   H  ...  5.0  4.0  4.0  1.0   9.0  11.0  1.0  4.0  0.0
#
#         AR
# 11108  0.0
# ...

# %%
#3 홈팀과 어웨이팀 이름 알려주는 프로그램 (복사해서 붙여 넣어주세요)
a = 1
b = 0
Team_List = ["Liverpool","Arsenal","Coventry","Aston Villa","QPR","Chelsea","Blackburn","Sheffield Weds","Man City","Oldham","Sheffield United","Newcastle","Leeds","Southampton","Everton","West Ham","Wimbledon","Norwich","Man United","Tottenham","Ipswich","Swindon","Crystal Palace","Nott'm Forest","Leicester","Middlesbrough","Bolton","Derby","Sunderland","Barnsley","Charlton","Bradford","Watford","Fulham"]
for c in Team_List :
  print("(",a,")"," : ", Team_List[b])
  a = a+1
  b = b+1

print("_____________________________________________________________________________________________________")
print("주의 사항_1 : 만약 자신이 원하는 팀이 없을 경우 직접 검색해 영어로 넣어주세요.")
print("주의 사항_2 : 만약에 결과가 안나올 경우 당황하지 마시고 csv파일에 있는 이름을 붙여 넣어주세요.")
# Out:
# ( 1 )  :  Liverpool
# ( 2 )  :  Arsenal
# ( 3 )  :  Coventry
# ( 4 )  :  Aston Villa
# ( 5 )  :  QPR
# ( 6 )  :  Chelsea
# ( 7 )  :  Blackburn
# ( 8 )  :  Sheffield Weds
# ( 9 )  :  Man City
# ( 10 )  :  Oldham
# ( 11 )  :  Sheffield United
# ( 12 )  :  Newcastle
# ( 13 )  :  Leeds
# ( 14 )  :  Southampton
# ( 15 )  :  Everton
# ( 16 )  :  West Ham
# ( 17 )  :  Wimbledon
# ( 18 )  :  Norwich
# ( 19 )  :  Man United
# ( 20 )  :  Tottenham
# ( 21 )  :  Ipswich
# ( 22 )  :  Swindon
# ( 23 )  :  Crystal Palace
# ( 24 )  :  Nott'm Forest
# ( 25 )  :  Leicester
# ( 26 )  :  Middlesbrough
# ( 27 )  :  Bolton
# ( 28 )  :  Derby
# ( 29 )  :  Sunderland
# ( 30 )  :  Barnsley
# ( 31 )  :  Charlton
# ( 32 )  :  Bradford
# ( 33 )  :  Watford
# ( 34 )  :  Fulham
# _____________________________________________________________________________________________________
# 주의 사항_1 : 만약 자신이 원하는 팀이 없을 경우 직접 검색해 영어로 넣어주세요.
# 주의 사항_2 : 만약에 결과가 안나올 경우 당황하지 마시고 csv파일에 있는 이름을 붙여 넣어주세요.

# %%
#4 홈팀과 어웨이팀의 승패 (*위의 팀 알림이에서 복사해서 붙여 넣어주세요*)
print("보고싶은 팀을 선택해 주세요!!")
home_Team = input("Home Team : ")
away_Team = input("Away Team : ")
print("Selected team(Home : Away) : " + home_Team + " : " + away_Team)

result1 = pd.concat([data[data['HomeTeam']== home_Team], data[data['AwayTeam']== home_Team]]).sort_index()
result2 = pd.concat([result1[result1['AwayTeam']==away_Team]]).sort_index()
result2
# Out:
# 보고싶은 팀을 선택해 주세요!!
# Home Team : Watford
# Away Team : Fulham
# Selected team(Home : Away) : Watford : Fulham
#        Season              DateTime HomeTeam AwayTeam  FTHG  FTAG FTR  HTHG  \
# 5172  2006-07  2006-10-02T00:00:00Z  Watford   Fulham     3     3   D   1.0
# 9978  2018-19  2019-04-02T00:00:00Z  Watford   Fulham     4     1   H   1.0
#
#       HTAG HTR  ...  HST  AST   HC   AC    HF    AF   HY   AY   HR   AR
# 5172   0.0   H  ...  4.0  3.0  3.0  2.0  24.0  12.0  1.0  3.0  0.0  0.0
# 9978   1.0   D  ...  7.0  7.0  6.0  4.0  12.0   5.0  3.0  2.0  0.0  0.0
#
# [2 rows x 23 columns]

# %%
#5 data(PL_result) 정보 확인
data.info()
data.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11113 entries, 0 to 11112
# Data columns (total 23 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Season    11113 non-null  object
#  1   DateTime  11113 non-null  object
#  2   HomeTeam  11113 non-null  object
#  3   AwayTeam  11113 non-null  object
#  4   FTHG      11113 non-null  int64
#  5   FTAG      11113 non-null  int64
#  6   FTR       11113 non-null  object
#  7   HTHG      10189 non-null  float64
#  8   HTAG      10189 non-null  float64
#  9   HTR       10189 non-null  object
#  10  Referee   8289 non-null   object
#  11  HS        8289 non-null   float64
#  12  AS        8289 non-null   float64
#  13  HST       8289 non-null   float64
#  14  AST       8289 non-null   float64
#  15  HC        8289 non-null   float64
#  16  AC        8289 non-null   float64
#  17  HF        8289 non-null   float64
#  18  AF        8289 non-null   float64
# ...

# %%
#6 불필요한 열의 내용은 제거한다.
data.drop(['DateTime','HTHG','HTAG','HTR','Referee', 'HS', 'AS','HST','AST', 'HC', 'AC', 'HF','AF', 'HY', 'AY', 'HR', 'AR']
              , axis=1, inplace=True)
data
# Out:
#         Season     HomeTeam        AwayTeam  FTHG  FTAG FTR
# 0      1993-94      Arsenal        Coventry     0     3   A
# 1      1993-94  Aston Villa             QPR     4     1   H
# 2      1993-94      Chelsea       Blackburn     1     2   A
# 3      1993-94    Liverpool  Sheffield Weds     2     0   H
# 4      1993-94     Man City           Leeds     1     1   D
# ...        ...          ...             ...   ...   ...  ..
# 11108  2021-22  Aston Villa       Tottenham     0     4   A
# 11109  2021-22    Brentford        West Ham     2     0   H
# 11110  2021-22    Leicester  Crystal Palace     2     1   H
# 11111  2021-22      Norwich         Burnley     2     0   H
# 11112  2021-22     Man City       Liverpool     2     2   D
#
# [11113 rows x 6 columns]

# %%
#7 새로운 열 내용으로 채우기
data.replace({'H' : 0, 'D' : 1, 'A' : 2}, inplace=True)
data
# Out:
#         Season     HomeTeam        AwayTeam  FTHG  FTAG  FTR
# 0      1993-94      Arsenal        Coventry     0     3    2
# 1      1993-94  Aston Villa             QPR     4     1    0
# 2      1993-94      Chelsea       Blackburn     1     2    2
# 3      1993-94    Liverpool  Sheffield Weds     2     0    0
# 4      1993-94     Man City           Leeds     1     1    1
# ...        ...          ...             ...   ...   ...  ...
# 11108  2021-22  Aston Villa       Tottenham     0     4    2
# 11109  2021-22    Brentford        West Ham     2     0    0
# 11110  2021-22    Leicester  Crystal Palace     2     1    0
# 11111  2021-22      Norwich         Burnley     2     0    0
# 11112  2021-22     Man City       Liverpool     2     2    1
#
# [11113 rows x 6 columns]

# %%
#8 unique를 통해 개별 컬럼 내에 유일한 값을 리스트화
team_name = list(data["HomeTeam"].unique())

data_team = pd.DataFrame(columns=team_name, index=["골", "득실"])

#8 골득실 data_team에 널기
for i in team_name:
    data_team[i].골 = sum(data["FTHG"][data["HomeTeam"]== i])
    data_team[i].골 += sum(data["FTAG"][data["AwayTeam"] == i])
    data_team[i].득실 = sum(data["FTAG"][data["HomeTeam"] == i])
    data_team[i].골 += sum(data["FTHG"][data["AwayTeam"] == i])
#8 팀순서는 알파베 ABC 순서   
data_team
# Out:
#    Arsenal Aston Villa Chelsea Liverpool Man City Newcastle Oldham  \
# 골     2593        1946    2516      2594     2156      2187     77
# 득실     466         557     455       438      430       589     33
#
#    Sheffield United Southampton West Ham  ... Hull Stoke Burnley Blackpool  \
# 골               264        1707     2016  ...  359   710     547        96
# 득실               86         517      630  ...  145   213     190        37
#
#    Swansea Cardiff Bournemouth Brighton Huddersfield Brentford
# 골      519     136         423      305          128        68
# 득실     170      73         148      122           56        19
#
# [2 rows x 50 columns]

# %%
#8 전치 행렬 전환한다.
data_team = data_team.T
data_team
# Out:
#                      골   득실
# Arsenal           2593  466
# Aston Villa       1946  557
# Chelsea           2516  455
# Liverpool         2594  438
# Man City          2156  430
# Newcastle         2187  589
# Oldham              77   33
# Sheffield United   264   86
# Southampton       1707  517
# West Ham          2016  630
# Norwich            685  248
# Tottenham         2450  591
# Everton           2233  607
# Ipswich            321  105
# Leeds             1052  265
# Wimbledon          570  175
# Blackburn         1357  363
# Coventry           597  171
# Man United        2719  411
# QPR                494  158
# Sheffield Weds     595  161
# Swindon            102   45
# Crystal Palace     853  298
# Leicester         1274  386
# Nott'm Forest      320   93
# Bolton            1007  313
# Middlesbrough      985  328
# Derby              514  177
# Sunderland        1145  371
# Barnsley            84   35
# Charlton           586  198
# Watford            579  227
# ...

# %%
data_team = data_team.reset_index()
data_team.rename(columns = {'index' : '팀'}, inplace = True)
df_team_G = data_team.sort_values("골", ascending=False)

# %%
#9 seaborn을 이용해서 골득실 그래프로 만들기(한글 깨짐 현상으로 인한 영어 사용)
figure, (ax1,ax2) = plt.subplots(nrows = 1, ncols =2 ) 
figure.set_size_inches(20,16)
sns.barplot(data=df_team_G, x="골", y="팀", ax=ax1)
sns.barplot(data=df_team_G, x="득실", y="팀", ax=ax2)
ax1.set_xlabel("골", fontsize=20)
ax2.set_xlabel("전체 득실", fontsize=20)
# Out:
# Text(0.5, 0, '전체 득실')

# %%
#10 승률 그래프제작 
a = 0

#10 새로운 열인 win rate 생성하고 삽입하기
data_team.insert(3, "승률", 0)

#10 2000년대 이후로 설정
i = 0
for i in range(0, 10802):
    season = (data["Season"].loc[i]).split("-")
    mm = int(season[0])
    if mm < 2000:
        data.drop(i, inplace=True)
#10 team이름의 홈팀에서 이긴 경기를 총 경기수로 나누고 100을 곱한 후 2자리에서 반올림한다.
for name in team_name:
    All_match = sum(data["HomeTeam"]==name) + sum(data["AwayTeam"]==name)
    Win_match = sum((data["HomeTeam"]==name) & (data["FTR"]==0))
    Win_match += sum((data["AwayTeam"]==name) & (data["FTR"]==2))
    if All_match == 0:
        continue
    data_team["승률"].loc[a] = round((Win_match/All_match) * 100, 1)
    a = a + 1
    
data_team
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
#                    팀     골   득실    승률
# 0            Arsenal  2593  466  56.2
# 1        Aston Villa  1946  557  31.2
# 2            Chelsea  2516  455  59.1
# 3          Liverpool  2594  438  55.2
# 4           Man City  2156  430  53.4
# 5          Newcastle  2187  589  33.9
# 6             Oldham    77   33  27.2
# 7   Sheffield United   264   86  32.0
# 8        Southampton  1707  517  33.1
# 9           West Ham  2016  630  21.6
# 10           Norwich   685  248  46.9
# 11         Tottenham  2450  591  38.4
# 12           Everton  2233  607  38.2
# 13           Ipswich   321  105  38.7
# 14             Leeds  1052  265  33.5
# ...

# %%
#11 seaborn을 통해 승률 그래프 제작

figure, (ax1,ax2) = plt.subplots(nrows = 1, ncols =2 ) 
figure.set_size_inches(20,16)
sns.barplot(data=df_team_G, x="골", y="팀", ax=ax1)
sns.barplot(data=data_team.sort_values("승률", ascending=False), x="승률", y="팀", ax=ax2)
ax1.set_xlabel("골", fontsize=20)
ax2.set_xlabel("승률", fontsize=20)
# Out:
# Text(0.5, 0, '승률')

# %%
#모든 과정을 합쳤다.


#2 third package 불러오기
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %matplotlib inline


#한글 깨짐문제 해결
import matplotlib as mpl 
import matplotlib.font_manager as fm  

# !apt-get update -qq
# !apt-get install fonts-nanum* -qq

path = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf' 
font_name = fm.FontProperties(fname=path, size=10).get_name()
print(font_name)
plt.rc('font', family=font_name)

fm._rebuild()
mpl.rcParams['axes.unicode_minus'] = False

data = pd.read_csv("PL_result.csv",encoding='windows-1254')

#5 data(PL_result) 정보 확인
data.info()
data.isna().sum()

#6 불필요한 열의 내용은 제거한다.
data.drop(['DateTime','HTHG','HTAG','HTR','Referee', 'HS', 'AS','HST','AST', 'HC', 'AC', 'HF','AF', 'HY', 'AY', 'HR', 'AR']
              , axis=1, inplace=True)

#7 새로운 열 내용으로 채우기
data.replace({'H' : 0, 'D' : 1, 'A' : 2}, inplace=True)

#8 unique를 통해 개별 컬럼 내에 유일한 값을 리스트화
team_name = list(data["HomeTeam"].unique())

data_team = pd.DataFrame(columns=team_name, index=["골", "득실"])

#8 골득실 data_team에 널기
for i in team_name:
    data_team[i].골 = sum(data["FTHG"][data["HomeTeam"]== i])
    data_team[i].골 += sum(data["FTAG"][data["AwayTeam"] == i])
    data_team[i].득실 = sum(data["FTAG"][data["HomeTeam"] == i])
    data_team[i].골 += sum(data["FTHG"][data["AwayTeam"] == i])
#8 팀순서는 알파베 ABC 순서   
data_team

#8 전치 행렬 전환한다.
data_team = data_team.T
data_team

data_team = data_team.reset_index()
data_team.rename(columns = {'index' : '팀'}, inplace = True)
df_team_G = data_team.sort_values("골", ascending=False)

#9 seaborn을 이용해서 골득실 그래프로 만들기(한글 깨짐 현상으로 인한 영어 사용)
figure, (ax1,ax2) = plt.subplots(nrows = 1, ncols =2 ) 
figure.set_size_inches(20,16)
sns.barplot(data=df_team_G, x="골", y="팀", ax=ax1)
sns.barplot(data=df_team_G, x="득실", y="팀", ax=ax2)
ax1.set_xlabel("골", fontsize=20)
ax2.set_xlabel("전체 득실", fontsize=20)

#10 승률 그래프제작 
a = 0

#10 새로운 열인 win rate 생성하고 삽입하기
data_team.insert(3, "승률", 0)

#10 2000년대 이후로 설정
i = 0
for i in range(0, 10802):
    season = (data["Season"].loc[i]).split("-")
    mm = int(season[0])
    if mm < 2000:
        data.drop(i, inplace=True)
#10 team이름의 홈팀에서 이긴 경기를 총 경기수로 나누고 100을 곱한 후 2자리에서 반올림한다.
for name in team_name:
    All_match = sum(data["HomeTeam"]==name) + sum(data["AwayTeam"]==name)
    Win_match = sum((data["HomeTeam"]==name) & (data["FTR"]==0))
    Win_match += sum((data["AwayTeam"]==name) & (data["FTR"]==2))
    if All_match == 0:
        continue
    data_team["승률"].loc[a] = round((Win_match/All_match) * 100, 1)
    a = a + 1
    
data_team

#11 seaborn을 통해 승률 그래프 제작

figure, (ax1,ax2) = plt.subplots(nrows = 1, ncols =2 ) 
figure.set_size_inches(20,16)
sns.barplot(data=df_team_G, x="골", y="팀", ax=ax1)
sns.barplot(data=data_team.sort_values("승률", ascending=False), x="승률", y="팀", ax=ax2)
ax1.set_xlabel("골", fontsize=20)
ax2.set_xlabel("승률", fontsize=20)
# Out:
# NanumBarunGothic
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11113 entries, 0 to 11112
# Data columns (total 23 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Season    11113 non-null  object
#  1   DateTime  11113 non-null  object
#  2   HomeTeam  11113 non-null  object
#  3   AwayTeam  11113 non-null  object
#  4   FTHG      11113 non-null  int64
#  5   FTAG      11113 non-null  int64
#  6   FTR       11113 non-null  object
#  7   HTHG      10189 non-null  float64
#  8   HTAG      10189 non-null  float64
#  9   HTR       10189 non-null  object
#  10  Referee   8289 non-null   object
#  11  HS        8289 non-null   float64
#  12  AS        8289 non-null   float64
#  13  HST       8289 non-null   float64
#  14  AST       8289 non-null   float64
#  15  HC        8289 non-null   float64
#  16  AC        8289 non-null   float64
#  17  HF        8289 non-null   float64
#  18  AF        8289 non-null   float64
# ...
